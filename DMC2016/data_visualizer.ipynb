# %%
from data_utils import *

train_data = get_train_data()
test_data = get_test_data()

# %%
train_data.describe()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>colorCode</th>
#       <th>productGroup</th>
#       <th>quantity</th>
#       <th>price</th>
#       <th>rrp</th>
#       <th>voucherAmount</th>
#       <th>deviceID</th>
#       <th>returnQuantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>180000.000000</td>
#       <td>179988.000000</td>
#       <td>180000.000000</td>
#       <td>180000.000000</td>
#       <td>179988.000000</td>
#       <td>180000.000000</td>
#       <td>180000.000000</td>
#       <td>180000.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>2061.941383</td>
#       <td>5.979776</td>
#       <td>0.994117</td>
#       <td>30.722501</td>
#       <td>41.656848</td>
#       <td>0.978269</td>
#       <td>2.394061</td>
#       <td>0.495006</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1546.170085</td>
# ...

# %%
test_data.describe()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>colorCode</th>
#       <th>productGroup</th>
#       <th>quantity</th>
#       <th>price</th>
#       <th>rrp</th>
#       <th>voucherAmount</th>
#       <th>deviceID</th>
#       <th>returnQuantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>200000.000000</td>
#       <td>199982.000000</td>
#       <td>200000.000000</td>
#       <td>200000.000000</td>
#       <td>199982.000000</td>
#       <td>200000.000000</td>
#       <td>200000.000000</td>
#       <td>200000.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>2063.149230</td>
#       <td>6.175691</td>
#       <td>0.988880</td>
#       <td>30.450324</td>
#       <td>40.677977</td>
#       <td>1.045815</td>
#       <td>2.485060</td>
#       <td>0.504295</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1766.323441</td>
# ...

# %%
get_price_morethan_rrp(train_data).describe()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>price</th>
#       <th>rrp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>1729.000000</td>
#       <td>1729.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>54.632597</td>
#       <td>30.661168</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>34.724181</td>
#       <td>16.150606</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>14.000000</td>
#       <td>9.990000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>31.980000</td>
#       <td>15.990000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>51.800000</td>
#       <td>29.990000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>59.990000</td>
#       <td>40.000000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>439.980000</td>
#       <td>219.990000</td>
#     </tr>
# ...

# %%
train_data['quantity'].unique()
# Out:
# array([1, 0, 2, 3, 5, 4])

# %%
train_data.groupby(['quantity']).count()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>orderID</th>
#       <th>orderDate</th>
#       <th>articleID</th>
#       <th>colorCode</th>
#       <th>sizeCode</th>
#       <th>productGroup</th>
#       <th>price</th>
#       <th>rrp</th>
#       <th>voucherID</th>
#       <th>voucherAmount</th>
#       <th>customerID</th>
#       <th>deviceID</th>
#       <th>paymentMethod</th>
#       <th>returnQuantity</th>
#     </tr>
#     <tr>
#       <th>quantity</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2715</td>
#       <td>2715</td>
#       <td>2715</td>
#       <td>2715</td>
#       <td>2715</td>
#       <td>2715</td>
# ...

# %%
train_data.groupby(['quantity']).sum()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>colorCode</th>
#       <th>productGroup</th>
#       <th>price</th>
#       <th>rrp</th>
#       <th>voucherAmount</th>
#       <th>deviceID</th>
#       <th>returnQuantity</th>
#     </tr>
#     <tr>
#       <th>quantity</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5783093</td>
#       <td>17018.0</td>
#       <td>0.000000e+00</td>
#       <td>1.286647e+05</td>
#       <td>3125.00</td>
#       <td>6431</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>362849250</td>
#       <td>1051185.0</td>
#       <td>5.460359e+06</td>
#       <td>7.328339e+06</td>
#       <td>171923.49</td>
#       <td>421004</td>
#       <td>88154</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...
